# %% [raw]
# import matplotlib
# import matplotlib.pyplot as plt
# import matplotlib.ticker as mticker
# import matplotlib.dates as mdates
# import numpy as np

# %%
def graphRawFX():
    date, bid, ask = np.loadtxt('GBPUSD1d.txt', unpack=True, delimiter=',', converters={0:mdates.strpdate2num('%Y%m%d%H%M%S')})
    fig = plt.figure(figsize=(10,7))
    ax1 = plt.subplot2grid((40,40), (0,0), rowspan=40, colspan=40)

    ax1.plot(date,bid)
    ax1.plot(date,ask)

    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))

    plt.grid(True)
    plt.show()

# %%
graphRawFX()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 graphRawFX()
#
# Cell In[5], line 2, in graphRawFX()
#       1 def graphRawFX():
# ----> 2     date, bid, ask = np.loadtxt('GBPUSD1d.txt', unpack=True, delimiter=',', converters={0:mdates.strpdate2num('%Y%m%d%H%M%S')})
#       3     fig = plt.figure(figsize=(10,7))
#       4     ax1 = plt.subplot2grid((40,40), (0,0), rowspan=40, colspan=40)
#
# NameError: name 'np' is not defined

# %%
import matplotlib.dates as mdates
import numpy as np
# 1. ADD THIS IMPORT
from datetime import datetime 

def graphRawFX():
    # 2. UPDATE THE CONVERTERS DICTIONARY
    date_converter = lambda x: mdates.date2num(datetime.strptime(x.decode('ascii'), '%Y%m%d%H%M%S'))
    
    date, bid, ask = np.loadtxt('GBPUSD1d.txt', unpack=True,
                               delimiter=',',
                               converters={0: date_converter}) # Use the new converter here

    fig = plt.figure(figsize=(10,7))
    ax1 = plt.subplot2grid((40,40), (0,0), rowspan=40, colspan=40)

    ax1.plot(date,bid)
    ax1.plot(date,ask)

    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))

    plt.grid(True)
    plt.show()

graphRawFX()
